# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import os
count=0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        count += 1
        if count == 5:
            break
    if count == 5:  # ensure we stop outer loop too
        break
            
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/efficient_net_b0_cbam/tensorflow2/default/1/efficientnet_b0_new_model.h5
# /kaggle/input/efficient_net_b0/tensorflow2/default/1/efficientnet_b0_best_model (1).h5
# /kaggle/input/efficient_net_b0/tensorflow2/default/1/efficientnet_b0_best_model.h5
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/Tomato___Late_blight/1e5ba644-efeb-4bd3-b878-a0606cf8a992___RS_Late.B 6272_flipLR.JPG
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/Tomato___Late_blight/3dcee9ed-43bb-45a9-8cff-641b3dd62179___RS_Late.B 5324.JPG

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model
import math
# Out:
# 2025-06-30 09:32:12.506940: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751275932.710704      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751275932.770734      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
TRAIN_DIR = "/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"
VAL_DIR = "/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid"
IMAGE_SIZE=(224,224)
BATCH_SIZE=32

# Normalize images
def preprocess(img, label):
    img = tf.cast(img, tf.float32) / 255.0
    return img, label
    
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=True
).map(preprocess).repeat().prefetch(tf.data.AUTOTUNE)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    VAL_DIR,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=False
)
class_names=val_ds.class_names
val_ds=val_ds.map(preprocess).prefetch(tf.data.AUTOTUNE)
# Out:
# Found 70295 files belonging to 38 classes.
# I0000 00:00:1751275985.598565      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 17572 files belonging to 38 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model
import math

# %%
def se_block(inputs, se_ratio=0.25):
    filters = inputs.shape[-1]
    se_filters = max(1, int(filters * se_ratio))
    se = layers.GlobalAveragePooling2D()(inputs)
    se = layers.Reshape((1, 1, filters))(se)
    se = layers.Conv2D(se_filters, 1, activation='relu')(se)
    se = layers.Conv2D(filters, 1, activation='sigmoid')(se)
    return layers.Multiply()([inputs, se])
    

def cbam_block(inputs, reduction_ratio=16):
    # Channel Attention
    channel_avg = layers.GlobalAveragePooling2D()(inputs)
    channel_max = layers.GlobalMaxPooling2D()(inputs)
    
    shared_dense = tf.keras.Sequential([
        layers.Dense(inputs.shape[-1] // reduction_ratio, activation='relu'),
        layers.Dense(inputs.shape[-1])
    ])

    avg_out = shared_dense(channel_avg)
    max_out = shared_dense(channel_max)

    channel_attention = layers.Add()([avg_out, max_out])
    channel_attention = layers.Activation('sigmoid')(channel_attention)
    channel_attention = layers.Reshape((1, 1, inputs.shape[-1]))(channel_attention)
    x = layers.Multiply()([inputs, channel_attention])

    # Spatial Attention using only Keras layers
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(x)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(x)
    concat = layers.Concatenate(axis=-1)([avg_pool, max_pool])
    spatial_attention = layers.Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    x = layers.Multiply()([x, spatial_attention])

    return x
    

def mbconv_block(inputs, out_channels, expansion_factor, kernel_size, strides, se_ratio=0.25):
    in_channels = inputs.shape[-1]
    x = inputs

    # Expansion phase
    if expansion_factor != 1:
        x = layers.Conv2D(in_channels * expansion_factor, 1, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('swish')(x)

    # Depthwise conv
    x = layers.DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Squeeze-and-Excitation
    x = se_block(x, se_ratio=se_ratio)

    # Projection phase
    x = layers.Conv2D(out_channels, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Skip connection
    if strides == 1 and in_channels == out_channels:
        x = layers.Add()([inputs, x])
    
    return x
    

def EfficientNetB0_custom(input_shape=(224,224, 3), num_classes=38, dropout_rate=0.2):
    inputs = tf.keras.Input(shape=input_shape)

    # Stem
    x = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # MBConv blocks (adapted from official B4 config)
    # (repeats, out_channels, kernel_size, strides)
    x = mbconv_block(x,out_channels=16,expansion_factor=1,kernel_size=3,strides=1)
    block_configs = [
        (2, 24, 3, 2),
        (2, 40, 5, 2),
        (3, 80, 3, 2),
        (3, 112, 5, 1),
        (4, 192, 5, 2),
        (1, 320, 3, 1),
    ]

    expansion_factor = 6
    for repeats, out_channels, kernel_size, strides in block_configs:
        for i in range(repeats):
            x = mbconv_block(
                x,
                out_channels=out_channels,
                expansion_factor=expansion_factor,
                kernel_size=kernel_size,
                strides=strides if i == 0 else 1
            )

    # Head
    x = layers.Conv2D(1280, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('swish')(x)

    # Convolutional Block Attention Module
    x = cbam_block(x)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# %%
model_e_cbam = EfficientNetB0_custom()

# %%
model_e_cbam.load_weights('/kaggle/input/efficient_net_b0_cbam/tensorflow2/default/1/efficientnet_b0_new_model.h5')

# %%
for i, layer in enumerate(model_e_cbam.layers):
    output_shape = getattr(layer, 'output_shape', 'N/A')
    print(f"{i:02d}. {layer.name:30s} --> Output shape: {output_shape}")
# Out:
# 00. input_layer                    --> Output shape: N/A
# 01. conv2d                         --> Output shape: N/A
# 02. batch_normalization            --> Output shape: N/A
# 03. activation                     --> Output shape: N/A
# 04. depthwise_conv2d               --> Output shape: N/A
# 05. batch_normalization_1          --> Output shape: N/A
# 06. activation_1                   --> Output shape: N/A
# 07. global_average_pooling2d       --> Output shape: N/A
# 08. reshape                        --> Output shape: N/A
# 09. conv2d_1                       --> Output shape: N/A
# 10. conv2d_2                       --> Output shape: N/A
# 11. multiply                       --> Output shape: N/A
# 12. conv2d_3                       --> Output shape: N/A
# 13. batch_normalization_2          --> Output shape: N/A
# 14. conv2d_4                       --> Output shape: N/A
# 15. batch_normalization_3          --> Output shape: N/A
# 16. activation_2                   --> Output shape: N/A
# 17. depthwise_conv2d_1             --> Output shape: N/A
# 18. batch_normalization_4          --> Output shape: N/A
# 19. activation_3                   --> Output shape: N/A
# 20. global_average_pooling2d_1     --> Output shape: N/A
# 21. reshape_1                      --> Output shape: N/A
# 22. conv2d_5                       --> Output shape: N/A
# 23. conv2d_6                       --> Output shape: N/A
# 24. multiply_1                     --> Output shape: N/A
# 25. conv2d_7                       --> Output shape: N/A
# 26. batch_normalization_5          --> Output shape: N/A
# 27. conv2d_8                       --> Output shape: N/A
# 28. batch_normalization_6          --> Output shape: N/A
# 29. activation_4                   --> Output shape: N/A
# 30. depthwise_conv2d_2             --> Output shape: N/A
# 31. batch_normalization_7          --> Output shape: N/A
# 32. activation_5                   --> Output shape: N/A
# 33. global_average_pooling2d_2     --> Output shape: N/A
# 34. reshape_2                      --> Output shape: N/A
# 35. conv2d_9                       --> Output shape: N/A
# 36. conv2d_10                      --> Output shape: N/A
# 37. multiply_2                     --> Output shape: N/A
# 38. conv2d_11                      --> Output shape: N/A
# 39. batch_normalization_8          --> Output shape: N/A
# 40. add                            --> Output shape: N/A
# 41. conv2d_12                      --> Output shape: N/A
# 42. batch_normalization_9          --> Output shape: N/A
# 43. activation_6                   --> Output shape: N/A
# 44. depthwise_conv2d_3             --> Output shape: N/A
# 45. batch_normalization_10         --> Output shape: N/A
# 46. activation_7                   --> Output shape: N/A
# 47. global_average_pooling2d_3     --> Output shape: N/A
# 48. reshape_3                      --> Output shape: N/A
# 49. conv2d_13                      --> Output shape: N/A
# 50. conv2d_14                      --> Output shape: N/A
# 51. multiply_3                     --> Output shape: N/A
# 52. conv2d_15                      --> Output shape: N/A
# 53. batch_normalization_11         --> Output shape: N/A
# 54. conv2d_16                      --> Output shape: N/A
# 55. batch_normalization_12         --> Output shape: N/A
# 56. activation_8                   --> Output shape: N/A
# 57. depthwise_conv2d_4             --> Output shape: N/A
# 58. batch_normalization_13         --> Output shape: N/A
# 59. activation_9                   --> Output shape: N/A
# 60. global_average_pooling2d_4     --> Output shape: N/A
# 61. reshape_4                      --> Output shape: N/A
# 62. conv2d_17                      --> Output shape: N/A
# 63. conv2d_18                      --> Output shape: N/A
# 64. multiply_4                     --> Output shape: N/A
# 65. conv2d_19                      --> Output shape: N/A
# 66. batch_normalization_14         --> Output shape: N/A
# 67. add_1                          --> Output shape: N/A
# 68. conv2d_20                      --> Output shape: N/A
# 69. batch_normalization_15         --> Output shape: N/A
# 70. activation_10                  --> Output shape: N/A
# 71. depthwise_conv2d_5             --> Output shape: N/A
# 72. batch_normalization_16         --> Output shape: N/A
# 73. activation_11                  --> Output shape: N/A
# 74. global_average_pooling2d_5     --> Output shape: N/A
# 75. reshape_5                      --> Output shape: N/A
# 76. conv2d_21                      --> Output shape: N/A
# 77. conv2d_22                      --> Output shape: N/A
# 78. multiply_5                     --> Output shape: N/A
# 79. conv2d_23                      --> Output shape: N/A
# 80. batch_normalization_17         --> Output shape: N/A
# 81. conv2d_24                      --> Output shape: N/A
# 82. batch_normalization_18         --> Output shape: N/A
# 83. activation_12                  --> Output shape: N/A
# 84. depthwise_conv2d_6             --> Output shape: N/A
# 85. batch_normalization_19         --> Output shape: N/A
# 86. activation_13                  --> Output shape: N/A
# 87. global_average_pooling2d_6     --> Output shape: N/A
# 88. reshape_6                      --> Output shape: N/A
# 89. conv2d_25                      --> Output shape: N/A
# 90. conv2d_26                      --> Output shape: N/A
# 91. multiply_6                     --> Output shape: N/A
# 92. conv2d_27                      --> Output shape: N/A
# 93. batch_normalization_20         --> Output shape: N/A
# 94. add_2                          --> Output shape: N/A
# 95. conv2d_28                      --> Output shape: N/A
# 96. batch_normalization_21         --> Output shape: N/A
# 97. activation_14                  --> Output shape: N/A
# 98. depthwise_conv2d_7             --> Output shape: N/A
# 99. batch_normalization_22         --> Output shape: N/A
# 100. activation_15                  --> Output shape: N/A
# 101. global_average_pooling2d_7     --> Output shape: N/A
# 102. reshape_7                      --> Output shape: N/A
# 103. conv2d_29                      --> Output shape: N/A
# 104. conv2d_30                      --> Output shape: N/A
# 105. multiply_7                     --> Output shape: N/A
# 106. conv2d_31                      --> Output shape: N/A
# 107. batch_normalization_23         --> Output shape: N/A
# 108. add_3                          --> Output shape: N/A
# 109. conv2d_32                      --> Output shape: N/A
# 110. batch_normalization_24         --> Output shape: N/A
# 111. activation_16                  --> Output shape: N/A
# 112. depthwise_conv2d_8             --> Output shape: N/A
# 113. batch_normalization_25         --> Output shape: N/A
# 114. activation_17                  --> Output shape: N/A
# 115. global_average_pooling2d_8     --> Output shape: N/A
# 116. reshape_8                      --> Output shape: N/A
# 117. conv2d_33                      --> Output shape: N/A
# 118. conv2d_34                      --> Output shape: N/A
# 119. multiply_8                     --> Output shape: N/A
# 120. conv2d_35                      --> Output shape: N/A
# 121. batch_normalization_26         --> Output shape: N/A
# 122. conv2d_36                      --> Output shape: N/A
# 123. batch_normalization_27         --> Output shape: N/A
# 124. activation_18                  --> Output shape: N/A
# 125. depthwise_conv2d_9             --> Output shape: N/A
# 126. batch_normalization_28         --> Output shape: N/A
# 127. activation_19                  --> Output shape: N/A
# 128. global_average_pooling2d_9     --> Output shape: N/A
# 129. reshape_9                      --> Output shape: N/A
# 130. conv2d_37                      --> Output shape: N/A
# 131. conv2d_38                      --> Output shape: N/A
# 132. multiply_9                     --> Output shape: N/A
# 133. conv2d_39                      --> Output shape: N/A
# 134. batch_normalization_29         --> Output shape: N/A
# 135. add_4                          --> Output shape: N/A
# 136. conv2d_40                      --> Output shape: N/A
# 137. batch_normalization_30         --> Output shape: N/A
# 138. activation_20                  --> Output shape: N/A
# 139. depthwise_conv2d_10            --> Output shape: N/A
# 140. batch_normalization_31         --> Output shape: N/A
# 141. activation_21                  --> Output shape: N/A
# 142. global_average_pooling2d_10    --> Output shape: N/A
# 143. reshape_10                     --> Output shape: N/A
# 144. conv2d_41                      --> Output shape: N/A
# 145. conv2d_42                      --> Output shape: N/A
# 146. multiply_10                    --> Output shape: N/A
# 147. conv2d_43                      --> Output shape: N/A
# 148. batch_normalization_32         --> Output shape: N/A
# 149. add_5                          --> Output shape: N/A
# 150. conv2d_44                      --> Output shape: N/A
# 151. batch_normalization_33         --> Output shape: N/A
# 152. activation_22                  --> Output shape: N/A
# 153. depthwise_conv2d_11            --> Output shape: N/A
# 154. batch_normalization_34         --> Output shape: N/A
# 155. activation_23                  --> Output shape: N/A
# 156. global_average_pooling2d_11    --> Output shape: N/A
# 157. reshape_11                     --> Output shape: N/A
# 158. conv2d_45                      --> Output shape: N/A
# 159. conv2d_46                      --> Output shape: N/A
# 160. multiply_11                    --> Output shape: N/A
# 161. conv2d_47                      --> Output shape: N/A
# 162. batch_normalization_35         --> Output shape: N/A
# 163. conv2d_48                      --> Output shape: N/A
# 164. batch_normalization_36         --> Output shape: N/A
# 165. activation_24                  --> Output shape: N/A
# 166. depthwise_conv2d_12            --> Output shape: N/A
# 167. batch_normalization_37         --> Output shape: N/A
# 168. activation_25                  --> Output shape: N/A
# 169. global_average_pooling2d_12    --> Output shape: N/A
# 170. reshape_12                     --> Output shape: N/A
# 171. conv2d_49                      --> Output shape: N/A
# 172. conv2d_50                      --> Output shape: N/A
# 173. multiply_12                    --> Output shape: N/A
# 174. conv2d_51                      --> Output shape: N/A
# 175. batch_normalization_38         --> Output shape: N/A
# 176. add_6                          --> Output shape: N/A
# 177. conv2d_52                      --> Output shape: N/A
# 178. batch_normalization_39         --> Output shape: N/A
# 179. activation_26                  --> Output shape: N/A
# 180. depthwise_conv2d_13            --> Output shape: N/A
# 181. batch_normalization_40         --> Output shape: N/A
# 182. activation_27                  --> Output shape: N/A
# 183. global_average_pooling2d_13    --> Output shape: N/A
# 184. reshape_13                     --> Output shape: N/A
# 185. conv2d_53                      --> Output shape: N/A
# 186. conv2d_54                      --> Output shape: N/A
# 187. multiply_13                    --> Output shape: N/A
# 188. conv2d_55                      --> Output shape: N/A
# 189. batch_normalization_41         --> Output shape: N/A
# 190. add_7                          --> Output shape: N/A
# 191. conv2d_56                      --> Output shape: N/A
# 192. batch_normalization_42         --> Output shape: N/A
# 193. activation_28                  --> Output shape: N/A
# 194. depthwise_conv2d_14            --> Output shape: N/A
# 195. batch_normalization_43         --> Output shape: N/A
# 196. activation_29                  --> Output shape: N/A
# 197. global_average_pooling2d_14    --> Output shape: N/A
# 198. reshape_14                     --> Output shape: N/A
# 199. conv2d_57                      --> Output shape: N/A
# 200. conv2d_58                      --> Output shape: N/A
# 201. multiply_14                    --> Output shape: N/A
# 202. conv2d_59                      --> Output shape: N/A
# 203. batch_normalization_44         --> Output shape: N/A
# 204. add_8                          --> Output shape: N/A
# 205. conv2d_60                      --> Output shape: N/A
# 206. batch_normalization_45         --> Output shape: N/A
# 207. activation_30                  --> Output shape: N/A
# 208. depthwise_conv2d_15            --> Output shape: N/A
# 209. batch_normalization_46         --> Output shape: N/A
# 210. activation_31                  --> Output shape: N/A
# 211. global_average_pooling2d_15    --> Output shape: N/A
# 212. reshape_15                     --> Output shape: N/A
# 213. conv2d_61                      --> Output shape: N/A
# 214. conv2d_62                      --> Output shape: N/A
# 215. multiply_15                    --> Output shape: N/A
# 216. conv2d_63                      --> Output shape: N/A
# 217. batch_normalization_47         --> Output shape: N/A
# 218. conv2d_64                      --> Output shape: N/A
# 219. batch_normalization_48         --> Output shape: N/A
# 220. activation_32                  --> Output shape: N/A
# 221. global_average_pooling2d_16    --> Output shape: N/A
# 222. global_max_pooling2d           --> Output shape: N/A
# 223. sequential                     --> Output shape: (None, 1280)
# 224. add_9                          --> Output shape: N/A
# 225. activation_33                  --> Output shape: N/A
# 226. reshape_16                     --> Output shape: N/A
# 227. multiply_16                    --> Output shape: N/A
# 228. lambda                         --> Output shape: N/A
# 229. lambda_1                       --> Output shape: N/A
# 230. concatenate                    --> Output shape: N/A
# 231. conv2d_65                      --> Output shape: N/A
# 232. multiply_17                    --> Output shape: N/A
# 233. global_average_pooling2d_17    --> Output shape: N/A
# 234. dropout                        --> Output shape: N/A
# 235. dense_2                        --> Output shape: N/A

# %%
# Image paths (replace with your list of 30 images)
image_names=['AppleCedarRust1','AppleCedarRust2','AppleCedarRust3','AppleCedarRust4','AppleScab1','AppleScab2','AppleScab3',
             'CornCommonRust1','CornCommonRust2','CornCommonRust3','PotatoEarlyBlight1','PotatoEarlyBlight2','PotatoEarlyBlight3',
             'PotatoEarlyBlight4','PotatoEarlyBlight5','PotatoHealthy1','PotatoHealthy2','TomatoEarlyBlight1','TomatoEarlyBlight2',
             'TomatoEarlyBlight3','TomatoEarlyBlight4','TomatoEarlyBlight5','TomatoEarlyBlight6','TomatoHealthy1','TomatoHealthy2',
             'TomatoHealthy3','TomatoHealthy4','TomatoYellowCurlVirus1','TomatoYellowCurlVirus2','TomatoYellowCurlVirus3','TomatoYellowCurlVirus4',
             'TomatoYellowCurlVirus5','TomatoYellowCurlVirus6']
image_paths = [f"/kaggle/input/new-plant-diseases-dataset/test/test/{img}.JPG" for img in image_names]

# %%
def get_nth_last_conv_layer_name(model, n=1):
    conv_layers = [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)]
    if len(conv_layers) < n:
        raise ValueError(f"Model has only {len(conv_layers)} Conv2D layers, can't get {n}-th last.")
    return conv_layers[-n].name

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# Grad-CAM++ Function
def gradCAM_plus_plus(img, model, last_conv_layer_name):
    grad_model = tf.keras.models.Model(
        inputs=[model.inputs],
        outputs=[model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape1:
        with tf.GradientTape() as tape2:
            with tf.GradientTape() as tape3:
                conv_outputs, predictions = grad_model(img)
                pred_index = tf.argmax(predictions[0])
                class_channel = predictions[:, pred_index]

            grads = tape3.gradient(class_channel, conv_outputs)
        first_derivative = grads
        second_derivative = tape2.gradient(grads, conv_outputs)
    third_derivative = tape1.gradient(second_derivative, conv_outputs)

    conv_outputs = conv_outputs[0]
    first_derivative = first_derivative[0]
    second_derivative = second_derivative[0]
    third_derivative = third_derivative[0]

    global_sum = np.sum(conv_outputs.numpy(), axis=(0, 1))
    alpha_num = second_derivative.numpy()
    alpha_denom = 2 * second_derivative.numpy() + third_derivative.numpy() * global_sum[np.newaxis, np.newaxis, :]
    alpha_denom = np.where(alpha_denom != 0.0, alpha_denom, 1e-10)

    alphas = alpha_num / alpha_denom
    weights = np.maximum(first_derivative.numpy(), 0.0)
    deep_linearization_weights = np.sum(alphas * weights, axis=(0, 1))

    heatmap = np.sum(deep_linearization_weights * conv_outputs.numpy(), axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap) + 1e-8

    return heatmap

# Outline with Adaptive Threshold
def draw_gradcam_fill_and_outline(heatmap, original_img, threshold_ratio=0.5, 
                                   fill_color=(255, 150, 150), outline_color=(0, 255, 0),
                                   fill_alpha=0.4, outline_thickness=1):
    if original_img.max() <= 1.0:
        img_uint8 = (original_img * 255).astype(np.uint8)
    else:
        img_uint8 = original_img.copy()

    heatmap_resized = cv2.resize(heatmap, (img_uint8.shape[1], img_uint8.shape[0]))
    heatmap_resized = np.uint8(255 * heatmap_resized)
    threshold = int(threshold_ratio * 255)
    _, binary_mask = cv2.threshold(heatmap_resized, threshold, 255, cv2.THRESH_BINARY)

    kernel = np.ones((5, 5), np.uint8)
    cleaned_mask = cv2.morphologyEx(binary_mask, cv2.MORPH_OPEN, kernel)
    cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_CLOSE, kernel)

    overlay = np.full_like(img_uint8, fill_color, dtype=np.uint8)
    mask_3ch = np.stack([cleaned_mask]*3, axis=-1) // 255
    filled_img = np.where(mask_3ch, cv2.addWeighted(img_uint8, 1 - fill_alpha, overlay, fill_alpha, 0), img_uint8)

    contours, _ = cv2.findContours(cleaned_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    outlined = cv2.drawContours(filled_img.copy(), contours, -1, outline_color, outline_thickness)

    return (outlined / 255.0) if original_img.max() <= 1.0 else outlined

# Grad-CAM++ for multiple images
last_conv_layer_name = get_nth_last_conv_layer_name(model_e_cbam,n=43)  # Update as needed
output_dir = "./gradcam_outputs"
os.makedirs(output_dir, exist_ok=True)

for i, img_path in enumerate(image_paths):
    if i==12 or i==20:
        
        # Extract true class name from file path (modify based on your folder structure)
        true_class = image_names[i]
        
        # Load and preprocess
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0) / 255.0

        # Predict class
        preds = model_e_cbam.predict(img_array)
        pred_idx = np.argmax(preds)
        pred_class = class_names[pred_idx]

        print(f"[{i+1}] True Class: {true_class} | Predicted Class: {pred_class}")

        # Grad-CAM++
        heatmap = gradCAM_plus_plus(img_array, model_e_cbam, last_conv_layer_name)
        
        percentile = 85
        threshold_value = np.percentile(heatmap, percentile)
        threshold_ratio = threshold_value / (np.max(heatmap) + 1e-8)

        outlined_img = draw_gradcam_fill_and_outline(heatmap, img_array[0], threshold_ratio=threshold_ratio)

        plt.figure(figsize=(12, 5))
        plt.suptitle(f"True: {true_class} | Predicted: {pred_class}", fontsize=14)

        plt.subplot(1, 3, 1)
        plt.title("Original Image")
        plt.imshow(img_array[0])
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.title("Grad-CAM++ Heatmap")
        plt.imshow(heatmap, cmap='jet')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.title("Outlined Grad-CAM++ Region")
        plt.imshow(outlined_img)
        plt.axis('off')

        plt.tight_layout()
        plt.savefig(f'gradcam_output_{i+1}.jpg')
        plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751275995.566718      65 service.cc:148] XLA service 0x7d36d4003d60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751275995.567473      65 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1751275996.225361      65 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# I0000 00:00:1751276000.408485      65 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor']]
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
# [13] True Class: PotatoEarlyBlight3 | Predicted Class: Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [21] True Class: TomatoEarlyBlight4 | Predicted Class: Tomato___Early_blight
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor']]
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)
